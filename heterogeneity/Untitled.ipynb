# %%
import json

# %%
# %run heterogeneity.py
# Out:
# Starting Cox Regression Simulation...
# Running 3000 simulations in parallel...
# Using 15 processes
# Save files: False
#
# Summary statistics:
#          euclidean    manhattan       cosine     survival      privacy  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean      1.379686     8.889692     0.989283  1339.476652     0.734899
# std       0.106356     0.704685     0.116500   860.330157     0.163271
# min       1.066688     7.142345     0.585452     0.111567     0.542811
# 25%       1.302227     8.430018     0.912140   440.624593     0.601628
# 50%       1.377473     8.866017     0.985715  1682.720207     0.634335
# 75%       1.465614     9.361906     1.073593  2184.424300     0.912967
# max       1.638253    10.607390     1.295343  2293.530617     1.000000
#
#             cindex
# count  3000.000000
# mean      0.502043
# std       0.026819
# min       0.438845
# 25%       0.480954
# 50%       0.503160
# 75%       0.519908
# max       0.598773
#
# ...

# %% [markdown]
# with open("sim_0_distances.json", 'r') as f:
#     distances = json.load(f)
#
# distances
