# %%
import json

# %%
# %run heterogeneity_mod.py
# Out:
# updated_test/in_loop_beta_random/samplesize_1000/stats_summary
# Starting Cox Regression Simulation...
# Running 500 simulations in parallel...
# Using 1 processes
# Save files: False
#
# Summary statistics:
#         euclidean   manhattan      cosine     survival     privacy  \
# count  500.000000  500.000000  500.000000   500.000000  500.000000
# mean    10.219563   13.083564    0.966621   345.943778    0.664386
# std      4.927501    6.668580    0.709383   388.563406    0.161210
# min      0.665496    0.820821    0.000002     0.012107    0.269556
# 25%      6.388926    7.972973    0.277805    43.671789    0.543922
# 50%      9.942615   12.372372    0.940583   192.166214    0.665239
# 75%     13.910047   17.637638    1.675511   528.669118    0.788490
# max     25.405626   35.895896    1.999958  1975.967889    0.976862
#
#        cindex_auditing  cindex_training          AIC
# count       500.000000       500.000000   500.000000
# ...
