# %%
import json

# %%
# %run heterogeneity.py
# Out:
# Starting Cox Regression Simulation...
# betas selected from laplace distribution
# Running 5000 simulations in parallel...
# Using 15 processes
# Save files: False
#
# Summary statistics:
#          euclidean    manhattan       cosine     survival      privacy  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      1.553157    11.211283     0.995971     0.849212     0.636505
# std       0.074217     0.537113     0.094218     1.186026     0.013067
# min       1.286300     9.308582     0.681570     0.000007     0.600826
# 25%       1.510569    10.866721     0.939954     0.087058     0.627535
# 50%       1.555841    11.240465     0.997140     0.347187     0.636187
# 75%       1.604335    11.583198     1.060268     1.121329     0.645294
# max       1.808630    12.464216     1.347488     7.123120     0.667370
#
#             cindex
# count  5000.000000
# mean      0.501526
# std       0.023380
# min       0.430451
# 25%       0.485615
# 50%       0.500654
# ...
