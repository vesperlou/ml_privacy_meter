# %%
import json

# %%
# %run heterogeneity.py
# Out:
# Starting Cox Regression Simulation...
# betas selected from laplace distribution
# Running 5000 simulations in parallel...
# Using 15 processes
# Save files: False
#
# Summary statistics:
#          euclidean    manhattan       cosine     survival      privacy  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.465768     1.111491     0.996948  1462.668995     0.757139
# std       0.136410     0.322280     0.341943   800.486314     0.163487
# min       0.146315     0.361951     0.210175     0.029963     0.495114
# 25%       0.370902     0.871207     0.747176   749.794704     0.641052
# 50%       0.452966     1.084381     1.015040  1845.215660     0.703244
# 75%       0.554807     1.317147     1.195086  2181.602532     0.948217
# max       0.921242     2.182547     1.831132  2299.857038     1.000000
#
#             cindex
# count  5000.000000
# mean      0.499945
# std       0.034080
# min       0.392881
# 25%       0.480620
# 50%       0.498486
# ...
