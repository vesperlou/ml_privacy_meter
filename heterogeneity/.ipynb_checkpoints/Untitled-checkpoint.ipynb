# %%
import json

# %%
# %run heterogeneity.py
# Out:
# Starting Cox Regression Simulation...
# Running 1 simulations in parallel...
# Using 1 processes
# beta
# [ 0.25576133 -0.02777414 -0.02936494  0.0454344  -0.05628397 -0.0299188
#  -0.06071984  0.20730122 -0.03185641 -0.06864323]
#
# beta
# [-0.06071984 -0.11013094 -0.03185641  0.0454344   0.00836061 -0.06791316
#  -0.21785246 -0.02436062  0.25576133 -0.05988833]
#
#
# {'euclidean': 0.5231922761360892, 'manhattan': 1.189135480983844, 'cosine': 1.0283607862505986, 'survival': 2054.397441568221, 'privacy': 0.50658, 'cindex': 0.49971443359688733}
#
# [[0.2557613342331561, -0.02777414032090817, -0.029364937512952924, 0.04543439858909218, -0.05628397438060687, -0.02991880030382768, -0.06071983913819215, 0.20730121687084124, -0.03185640521365225, -0.06864322645629387], [-0.06071983913819215, -0.11013093829252069, -0.03185640521365225, 0.04543439858909218, 0.008360612453132616, -0.06791315572314563, -0.21785246152730753, -0.0243606232725782, 0.2557613342331561, -0.05988832874851076]]
#
# ...

# %%
with open("sim_0_distances.json", 'r') as f:
    distances = json.load(f)

distances
# Out:
# {'euclidean': 0.5239698554710962,
#  'manhattan': 1.305135376532239,
#  'cosine': 1.3988884090716953,
#  'survival': 2240.13416304488,
#  'privacy': 0.486615,
#  'cindex': 0.44933087467628435}
